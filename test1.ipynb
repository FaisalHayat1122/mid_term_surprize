# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("Ecommerce Dataset.xlsx")

# %%
df
# Out:
#       item_id          status  created_at  \
# 0      831156  order_refunded   4/25/2018
# 1      864213        canceled    6/1/2018
# 2      784089        canceled   3/15/2018
# 3      465260        complete    5/7/2017
# 4      846044        received   5/11/2018
# ...       ...             ...         ...
# 9995   680616        canceled  11/24/2017
# 9996   325420        canceled  11/25/2016
# 9997   649516        complete  11/20/2017
# 9998   391461        canceled   1/21/2017
# 9999   447254  order_refunded   4/15/2017
#
#                                       sku    price  qty_ordered  grand_total  \
# 0                     COMSAN5AA13CA206621   1188.0            1      1188.00
# 1                     MATHUA5AF70B5D6ADF3  36000.0            1     36000.00
# 2                     OTHPCB5A7D8A1240398  12000.0            2     24000.00
# 3                      KureshiC_141-kemei   1599.0            1      1599.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   item_id                10000 non-null  int64
#  1   status                 10000 non-null  object
#  2   created_at             10000 non-null  object
#  3   sku                    10000 non-null  object
#  4   price                  10000 non-null  float64
#  5   qty_ordered            10000 non-null  int64
#  6   grand_total            10000 non-null  float64
#  7   increment_id           10000 non-null  object
#  8   category_name_1        9997 non-null   object
#  9   sales_commission_code  7699 non-null   object
#  10  discount_amount        10000 non-null  float64
#  11  payment_method         10000 non-null  object
#  12  Working Date           10000 non-null  object
#  13  BI Status              10000 non-null  object
# ...

# %%
df.isnull().any
# Out:
# <bound method DataFrame.any of       item_id  status  created_at    sku  price  qty_ordered  grand_total  \
# 0       False   False       False  False  False        False        False
# 1       False   False       False  False  False        False        False
# 2       False   False       False  False  False        False        False
# 3       False   False       False  False  False        False        False
# 4       False   False       False  False  False        False        False
# ...       ...     ...         ...    ...    ...          ...          ...
# 9995    False   False       False  False  False        False        False
# 9996    False   False       False  False  False        False        False
# 9997    False   False       False  False  False        False        False
# 9998    False   False       False  False  False        False        False
# 9999    False   False       False  False  False        False        False
#
# ...

# %%
df.isnull()
# Out:
#       item_id  status  created_at    sku  price  qty_ordered  grand_total  \
# 0       False   False       False  False  False        False        False
# 1       False   False       False  False  False        False        False
# 2       False   False       False  False  False        False        False
# 3       False   False       False  False  False        False        False
# 4       False   False       False  False  False        False        False
# ...       ...     ...         ...    ...    ...          ...          ...
# 9995    False   False       False  False  False        False        False
# 9996    False   False       False  False  False        False        False
# 9997    False   False       False  False  False        False        False
# 9998    False   False       False  False  False        False        False
# 9999    False   False       False  False  False        False        False
#
#       increment_id  category_name_1  sales_commission_code  ...  \
# ...

# %%
df
# Out:
#       item_id          status  created_at  \
# 0      831156  order_refunded   4/25/2018
# 1      864213        canceled    6/1/2018
# 2      784089        canceled   3/15/2018
# 3      465260        complete    5/7/2017
# 4      846044        received   5/11/2018
# ...       ...             ...         ...
# 9995   680616        canceled  11/24/2017
# 9996   325420        canceled  11/25/2016
# 9997   649516        complete  11/20/2017
# 9998   391461        canceled   1/21/2017
# 9999   447254  order_refunded   4/15/2017
#
#                                       sku    price  qty_ordered  grand_total  \
# 0                     COMSAN5AA13CA206621   1188.0            1      1188.00
# 1                     MATHUA5AF70B5D6ADF3  36000.0            1     36000.00
# 2                     OTHPCB5A7D8A1240398  12000.0            2     24000.00
# 3                      KureshiC_141-kemei   1599.0            1      1599.00
# ...

# %%
df["Month"].sum
# Out:
# <bound method Series.sum of 0        4
# 1        6
# 2        3
# 3        5
# 4        5
#         ..
# 9995    11
# 9996    11
# 9997    11
# 9998     1
# 9999     4
# Name: Month, Length: 10000, dtype: int64>

# %%
df["Month"].count
# Out:
# <bound method Series.count of 0        4
# 1        6
# 2        3
# 3        5
# 4        5
#         ..
# 9995    11
# 9996    11
# 9997    11
# 9998     1
# 9999     4
# Name: Month, Length: 10000, dtype: int64>

# %%
df["status"].count
# Out:
# <bound method Series.count of 0       order_refunded
# 1             canceled
# 2             canceled
# 3             complete
# 4             received
#              ...
# 9995          canceled
# 9996          canceled
# 9997          complete
# 9998          canceled
# 9999    order_refunded
# Name: status, Length: 10000, dtype: object>

# %%
df.head(10)
# Out:
#    item_id          status created_at                     sku    price  \
# 0   831156  order_refunded  4/25/2018     COMSAN5AA13CA206621   1188.0
# 1   864213        canceled   6/1/2018     MATHUA5AF70B5D6ADF3  36000.0
# 2   784089        canceled  3/15/2018     OTHPCB5A7D8A1240398  12000.0
# 3   465260        complete   5/7/2017      KureshiC_141-kemei   1599.0
# 4   846044        received  5/11/2018     BAGVIT5AC4A6DD68342    310.0
# 5   869322        received   6/9/2018     WOFTOO5AA849648ADE4    999.0
# 6   396847        canceled   2/1/2017     infinix_Zero 4-Grey  22999.0
# 7   430606        canceled  3/24/2017         streets_SS-06-L   1000.0
# 8   510420        complete  6/11/2017          vitamin_Wipes    1275.0
# 9   821531        complete   4/8/2018  MEFBUY5A6B122D07266-40    699.0
#
#    qty_ordered  grand_total increment_id    category_name_1  \
# 0            1      1188.00    100516225          Computing
# 1            1     36000.00    100537896  Mobiles & Tablets
# ...

# %%
df.columns
# Out:
# Index(['item_id', 'status', 'created_at', 'sku', 'price', 'qty_ordered',
#        'grand_total', 'increment_id', 'category_name_1',
#        'sales_commission_code', 'discount_amount', 'payment_method',
#        'Working Date', 'BI Status', ' MV ', 'Year', 'Month', 'Customer Since',
#        'M-Y', 'FY', 'Customer ID'],
#       dtype='object')

# %%
df
# Out:
#       item_id          status  created_at  \
# 0      831156  order_refunded   4/25/2018
# 1      864213        canceled    6/1/2018
# 2      784089        canceled   3/15/2018
# 3      465260        complete    5/7/2017
# 4      846044        received   5/11/2018
# ...       ...             ...         ...
# 9995   680616        canceled  11/24/2017
# 9996   325420        canceled  11/25/2016
# 9997   649516        complete  11/20/2017
# 9998   391461        canceled   1/21/2017
# 9999   447254  order_refunded   4/15/2017
#
#                                       sku    price  qty_ordered  grand_total  \
# 0                     COMSAN5AA13CA206621   1188.0            1      1188.00
# 1                     MATHUA5AF70B5D6ADF3  36000.0            1     36000.00
# 2                     OTHPCB5A7D8A1240398  12000.0            2     24000.00
# 3                      KureshiC_141-kemei   1599.0            1      1599.00
# ...

# %%
df["Month"].sum
# Out:
# <bound method Series.sum of 0        4
# 1        6
# 2        3
# 3        5
# 4        5
#         ..
# 9995    11
# 9996    11
# 9997    11
# 9998     1
# 9999     4
# Name: Month, Length: 10000, dtype: int64>

# %%
df["Month"].count
# Out:
# <bound method Series.count of 0        4
# 1        6
# 2        3
# 3        5
# 4        5
#         ..
# 9995    11
# 9996    11
# 9997    11
# 9998     1
# 9999     4
# Name: Month, Length: 10000, dtype: int64>

# %%
df["payment_method"].count
# Out:
# <bound method Series.count of 0           Easypay
# 1           Easypay
# 2           Easypay
# 3               cod
# 4           Payaxis
#            ...
# 9995        Easypay
# 9996    jazzvoucher
# 9997            cod
# 9998        Payaxis
# 9999            cod
# Name: payment_method, Length: 10000, dtype: object>

# %%
df["payment_method"].sum
# Out:
# <bound method Series.sum of 0           Easypay
# 1           Easypay
# 2           Easypay
# 3               cod
# 4           Payaxis
#            ...
# 9995        Easypay
# 9996    jazzvoucher
# 9997            cod
# 9998        Payaxis
# 9999            cod
# Name: payment_method, Length: 10000, dtype: object>

# %%
import streamlit as st

# %%
st.title("Data is here")
# Out:
# 2025-04-30 20:06:01.799 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-30 20:06:02.347
# ...
#   command:
#
#     streamlit run C:\Users\User\AppData\Roaming\Python\Python313\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-04-30 20:06:02.349 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
import seaborn as sns

# %%
df
# Out:
#       item_id          status  created_at  \
# 0      831156  order_refunded   4/25/2018
# 1      864213        canceled    6/1/2018
# 2      784089        canceled   3/15/2018
# 3      465260        complete    5/7/2017
# 4      846044        received   5/11/2018
# ...       ...             ...         ...
# 9995   680616        canceled  11/24/2017
# 9996   325420        canceled  11/25/2016
# 9997   649516        complete  11/20/2017
# 9998   391461        canceled   1/21/2017
# 9999   447254  order_refunded   4/15/2017
#
#                                       sku    price  qty_ordered  grand_total  \
# 0                     COMSAN5AA13CA206621   1188.0            1      1188.00
# 1                     MATHUA5AF70B5D6ADF3  36000.0            1     36000.00
# 2                     OTHPCB5A7D8A1240398  12000.0            2     24000.00
# 3                      KureshiC_141-kemei   1599.0            1      1599.00
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of       item_id          status  created_at  \
# 0      831156  order_refunded   4/25/2018
# 1      864213        canceled    6/1/2018
# 2      784089        canceled   3/15/2018
# 3      465260        complete    5/7/2017
# 4      846044        received   5/11/2018
# ...       ...             ...         ...
# 9995   680616        canceled  11/24/2017
# 9996   325420        canceled  11/25/2016
# 9997   649516        complete  11/20/2017
# 9998   391461        canceled   1/21/2017
# 9999   447254  order_refunded   4/15/2017
#
#                                       sku    price  qty_ordered  grand_total  \
# 0                     COMSAN5AA13CA206621   1188.0            1      1188.00
# 1                     MATHUA5AF70B5D6ADF3  36000.0            1     36000.00
# 2                     OTHPCB5A7D8A1240398  12000.0            2     24000.00
# 3                      KureshiC_141-kemei   1599.0            1      1599.00
# ...
